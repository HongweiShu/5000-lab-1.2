# %% [raw]
# ---
# title: "Lab"
# author: "Hongwei Shu"
# format: revealjs
# ---

# %% [markdown]
# ## 1st page
#
# - Hello
#
# ## 2page
#
# - This is 2nd page
#
#
# ## 3rd page
#
# -Hello world
# ![killa](../images/pic2.png)
# ![NSV](../images/pic1.png)
#
#
# ## New page

# %%
import matplotlib.pyplot as plt
  

x = [1,2,3]

y = [2,4,1]

plt.plot(x, y)

plt.xlabel('x - axis')

plt.ylabel('y - axis')

plt.title('Lab graph')
plt.show()
